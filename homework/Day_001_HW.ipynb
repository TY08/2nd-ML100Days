# %%
#作業1
#The ubiquity of data today enables investors at any scale to make better investment decisions.The challenge is ingesting and interpreting the data to determine which data is useful, finding the signal in this sea of information.And help people make money.
#Market data (2007 to present) provided by Intrinio; News data (2007 to present) Source: Thomson Reuters
#CSV
#predict the stock change by news impact;predict a signed confidence value between -1 to 1; multiplied by the market-adjusted return of a given assetCode over a ten day window. If you expect a stock to have a large positive return--compared to the broad market--over the next ten days, you might assign it a large, positive confidenceValue (near 1.0). If you expect a stock to have a negative return, you might assign it a large, negative confidenceValue (near -1.0). If unsure, you might assign it a value near zero

# %%
#作業2
#提升業績:我定義提升業績為花費最小資源獲取最大利益，假設我們能預測哪些重點地方有更多的客戶，或是單程可以賺取更多的金錢，我們就能提前布局搶先其他業者;反之如果我們預測是淡季日我們也可以節省資源，在那幾天建議車隊用輪班的方式處理就好，其他人就可以休假去做別的事情
#想要預測哪些地方會有大單的客戶出現，或是哪幾天比較會有頻繁的客戶，第一點需要平常載客的路線跟時間還有收取的金額，每一台車都需要回報這些資料，這些資料是最直接的回饋，可藉由車上的手機直接收集;第二層我們可以想辦法找出這些時間可能跟其他什麼因素有關，例如飯店在有研討會或是婚禮的時候客人特別多，那如果能取得飯店被預約會議的時間就可以提早去布局
#資料收集的型態需彙整轉成CSV檔
#我們的答案就是單程的return(車上蒐集的資料)或是同時間內出現最多次載客次數(也是車上蒐集資料)，對照飯店會議時間,機場747客機出現時間,天氣預報等等因素當預測，看在哪個情境下最容易出現高頻或者大單交易，就可以安排車隊需要分散在哪些區域待命

# %%
#作業3

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    
    返回:
    mse -- MSE 評價指標
    """
    
    mse = MSE = sum(np.square(y-yp))/len(y)
    return mse

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 223.789
# The Mean absolute error is 12.040
